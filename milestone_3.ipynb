# %%
PATH_ROOT = 'data'
PATH_OUTPUT = 'output'
PATH_QUOTEBANK = PATH_ROOT + '/Quotebank'
PATH_TO_QUOTES = PATH_QUOTEBANK + '/quotes-{year}.json.bz2'

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import seaborn as sns

#NLP libraries
import spacy, nltk, gensim, sklearn
import pyLDAvis.gensim_models

import matplotlib.pyplot as plt
# %matplotlib inline  

import pickle
# Out:
# C:\Users\steph\miniconda3\envs\ada\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %% [markdown]
# # 1. Loading Data

# %% [markdown]
# ### Retrieve the labeled speakers

# %%
# First retrieve the dtypes of the corresponding columns
with open('output/speakers_labeled_dtypes.pickle', 'rb') as handle:
    speakers_labeled_dtypes = pickle.load(handle)

# %%
retrieved_labeled_speakers = pd.read_csv(PATH_OUTPUT + '/speakers_labeled.csv', dtype=speakers_labeled_dtypes)
retrieved_labeled_speakers.head()
# Out:
#    qid                                            aliases  \
# 0  Q23  ['Washington' 'President Washington' 'G. Washi...
# 1  Q23  ['Washington' 'President Washington' 'G. Washi...
# 2  Q23  ['Washington' 'President Washington' 'G. Washi...
# 3  Q23  ['Washington' 'President Washington' 'G. Washi...
# 4  Q23  ['Washington' 'President Washington' 'G. Washi...
#
#            date_of_birth    nationality gender   lastrevid ethnic_group  \
# 0  +1732-02-22T00:00:00Z  Great Britain   male  1395141751          NaN
# 1  +1732-02-22T00:00:00Z  Great Britain   male  1395141751          NaN
# 2  +1732-02-22T00:00:00Z  Great Britain   male  1395141751          NaN
# 3  +1732-02-22T00:00:00Z  Great Britain   male  1395141751          NaN
# 4  +1732-02-22T00:00:00Z  Great Britain   male  1395141751          NaN
#
#   US_congress_bio_ID        occupation                   party  \
# 0            W000178        politician  independent politician
# 1            W000178        politician  independent politician
# 2            W000178  military officer  independent politician
# 3            W000178  military officer  independent politician
# 4            W000178            farmer  independent politician
#
#   academic_degree              label  \
# 0             NaN  George Washington
# 1             NaN  George Washington
# 2             NaN  George Washington
# 3             NaN  George Washington
# 4             NaN  George Washington
#
#                                      candidacy  type          religion    age  \
# 0     1792 United States presidential election  item  Episcopal Church  289.0
# 1  1788–89 United States presidential election  item  Episcopal Church  289.0
# 2     1792 United States presidential election  item  Episcopal Church  289.0
# 3  1788–89 United States presidential election  item  Episcopal Church  289.0
# 4     1792 United States presidential election  item  Episcopal Church  289.0
#
#   age_group
# 0      >100
# 1      >100
# 2      >100
# 3      >100
# 4      >100

# %% [markdown]
# We can for example filter all speakers that are politicians.

# %%
politicians_df = retrieved_labeled_speakers[retrieved_labeled_speakers.occupation == 'politician']
politicians_df.head()
# Out:
#      qid                                            aliases  \
# 0    Q23  ['Washington' 'President Washington' 'G. Washi...
# 1    Q23  ['Washington' 'President Washington' 'G. Washi...
# 16   Q23  ['Washington' 'President Washington' 'G. Washi...
# 17   Q23  ['Washington' 'President Washington' 'G. Washi...
# 45  Q207  ['George Walker Bush' 'Bush Jr.' 'Dubya' 'GWB'...
#
#             date_of_birth               nationality gender   lastrevid  \
# 0   +1732-02-22T00:00:00Z             Great Britain   male  1395141751
# 1   +1732-02-22T00:00:00Z             Great Britain   male  1395141751
# 16  +1732-02-22T00:00:00Z  United States of America   male  1395141751
# 17  +1732-02-22T00:00:00Z  United States of America   male  1395141751
# 45  +1946-07-06T00:00:00Z  United States of America   male  1395142029
#
#    ethnic_group US_congress_bio_ID  occupation                   party  \
# 0           NaN            W000178  politician  independent politician
# 1           NaN            W000178  politician  independent politician
# 16          NaN            W000178  politician  independent politician
# 17          NaN            W000178  politician  independent politician
# 45          NaN                NaN  politician        Republican Party
#
#    academic_degree              label  \
# 0              NaN  George Washington
# 1              NaN  George Washington
# 16             NaN  George Washington
# 17             NaN  George Washington
# 45             NaN     George W. Bush
#
#                                       candidacy  type  \
# 0      1792 United States presidential election  item
# 1   1788–89 United States presidential election  item
# 16     1792 United States presidential election  item
# 17  1788–89 United States presidential election  item
# 45     2000 United States presidential election  item
#
#                    religion    age age_group
# 0          Episcopal Church  289.0      >100
# 1          Episcopal Church  289.0      >100
# 16         Episcopal Church  289.0      >100
# 17         Episcopal Church  289.0      >100
# 45  United Methodist Church   75.0       70s

# %%
### Retrieve environment related speakers

# %% [markdown]
# Let's get the Quotebank quotations related to environment from the year 2020

# %%
quotations_environment_related = pd.read_json(path_or_buf='data/quotes-2020-filtered.json')
quotations_environment_related
# Out:
#                                                            quotation
# 2020-01-01-000132  [ o ] ur collective failure to act strongly an...
# 2020-01-01-000363  2020 will see more youngsters defying conventi...
# 2020-01-01-000495  A circular economy development path could sign...
# 2020-01-01-000858  A path of resolve, of sustainable solutions. A...
# 2020-01-01-001549  All other waste or recyclables should be taken...
# ...                                                              ...
# 2020-04-16-069260  You're looking at anywhere from a 20 to 40% de...
# 2020-04-16-069275              You're not locking carbon in a vault,
# 2020-04-17-000463  The wind industry's rapid and continued growth...
# 2020-04-17-000605  Wind power provides long-term price stability,...
# 2020-04-17-000611  Years of hard work culminated with wind power ...
#
# [40596 rows x 1 columns]

# %%
#retrieved_labeled_speakers.index = retrieved_labeled_speakers.index.astype('int64')
#retrieved_labeled_speakers.index

# %%
default_speakers_attributes = ['label', 'aliases', 'nationality', 'gender', 'ethnic_group', 'occupation', 'party',
                               'US_congress_bio_ID', 'academic_degree', 'candidacy', 'religion', 'age', 'age_group']

def merge_quotations_with_speakers(speakers_df, quotations_df,
                                   speakers_attributes= default_speakers_attributes,
                                   quotations_attributes = ['quoteID', 'qids', 'urls'],
                                   year=2020):
    '''
    Merge the quotations with their speakers attributes based on the qid of the speaker
    
    Returns:
        The final df
    '''
    merged_chunks = []

    with pd.read_json(path_or_buf=PATH_TO_QUOTES.format(year=year), compression='bz2', lines=True, chunksize=500000) as df_reader:
        for chunk in df_reader:
            # filter the columns
            chunk = chunk[quotations_attributes]
            # check if chunk is environmentally related
            chunk = chunk[chunk.quoteID.isin(quotations_environment_related.index)]
            # Explode the chunk's speakers' qids
            chunk = chunk.explode('qids')
            # Merge chunk and speakers on qid
            merged_chunks.append(chunk.merge(right=retrieved_labeled_speakers[['qid'] + speakers_attributes], left_on='qids', right_on='qid'))

    return pd.concat(merged_chunks, ignore_index=True)

# %%
final_df = merge_quotations_with_speakers(retrieved_labeled_speakers, quotations_environment_related)
final_df
# Out:
#                   quoteID       qids  \
# 0       2020-01-24-004182   Q7199798
# 1       2020-02-07-004808    Q206017
# 2       2020-02-07-004808    Q206017
# 3       2020-02-07-001100    Q206017
# 4       2020-02-07-001100    Q206017
# ...                   ...        ...
# 237392  2020-02-04-109912    Q264374
# 237393  2020-02-04-109912    Q264374
# 237394  2020-02-04-109912    Q264374
# 237395  2020-02-04-109912    Q264374
# 237396  2020-02-23-041538  Q53473786
#
#                                                      urls        qid  \
# 0       [http://aninews.in/news/world/europe/piyush-go...   Q7199798
# 1            [http://www.desmogblog.com/patrick-michaels]    Q206017
# 2            [http://www.desmogblog.com/patrick-michaels]    Q206017
# 3            [http://www.desmogblog.com/patrick-michaels]    Q206017
# 4            [http://www.desmogblog.com/patrick-michaels]    Q206017
# ...                                                   ...        ...
# 237392  [http://www.newcastlestar.com.au/story/6614761...    Q264374
# 237393  [http://www.newcastlestar.com.au/story/6614761...    Q264374
# 237394  [http://www.newcastlestar.com.au/story/6614761...    Q264374
# 237395  [http://www.newcastlestar.com.au/story/6614761...    Q264374
# 237396  [https://www.nytimes.com/2020/02/23/world/aust...  Q53473786
#
#                    label                                            aliases  \
# 0           Piyush Goyal                                                NaN
# 1       Patrick Michaels  ['Patrick J. Michaels' 'Patrick J Michaels' 'P...
# 2       Patrick Michaels  ['Patrick J. Michaels' 'Patrick J Michaels' 'P...
# 3       Patrick Michaels  ['Patrick J. Michaels' 'Patrick J Michaels' 'P...
# 4       Patrick Michaels  ['Patrick J. Michaels' 'Patrick J Michaels' 'P...
# ...                  ...                                                ...
# 237392   Heather Wheeler                            ['Heather Kay Wheeler']
# 237393   Heather Wheeler                            ['Heather Kay Wheeler']
# 237394   Heather Wheeler                            ['Heather Kay Wheeler']
# 237395   Heather Wheeler                            ['Heather Kay Wheeler']
# 237396     Lesley Hughes                              ['Lesley Ann Hughes']
#
#                      nationality  gender ethnic_group          occupation  \
# 0                          India    male          NaN          politician
# 1       United States of America    male          NaN            lobbyist
# 2       United States of America    male          NaN  university teacher
# 3       United States of America    male          NaN            lobbyist
# 4       United States of America    male          NaN  university teacher
# ...                          ...     ...          ...                 ...
# 237392            United Kingdom  female          NaN          politician
# 237393            United Kingdom  female          NaN          politician
# 237394            United Kingdom  female          NaN          politician
# 237395            United Kingdom  female          NaN          politician
# 237396                 Australia  female          NaN           biologist
#
#                          party US_congress_bio_ID academic_degree  \
# 0       Bharatiya Janata Party                NaN             NaN
# 1                          NaN                NaN             NaN
# 2                          NaN                NaN             NaN
# 3                          NaN                NaN             NaN
# 4                          NaN                NaN             NaN
# ...                        ...                ...             ...
# 237392      Conservative Party                NaN             NaN
# 237393      Conservative Party                NaN             NaN
# 237394      Conservative Party                NaN             NaN
# 237395      Conservative Party                NaN             NaN
# 237396                     NaN                NaN             NaN
#
#                                    candidacy  religion   age age_group
# 0                                        NaN  Hinduism  57.0       50s
# 1                                        NaN       NaN  71.0       70s
# 2                                        NaN       NaN  71.0       70s
# 3                                        NaN       NaN  71.0       70s
# 4                                        NaN       NaN  71.0       70s
# ...                                      ...       ...   ...       ...
# 237392  2019 United Kingdom general election       NaN  62.0       60s
# 237393  2010 United Kingdom general election       NaN  62.0       60s
# 237394  2015 United Kingdom general election       NaN  62.0       60s
# 237395  2017 United Kingdom general election       NaN  62.0       60s
# 237396                                   NaN       NaN   NaN       NaN
#
# [237397 rows x 17 columns]
